# %%
r = load_player_sprites()
# Out:
# [[[  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]
#   ...
#   [  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]]
#
#  [[  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]
#   ...
#   [  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]]
#
#  [[  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]
#   ...
#   [  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]]
#
#  ...
#
#  [[  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]
#   ...
#   [  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]]
#
#  [[  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]
#   ...
#   [  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]]
#
#  [[  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]
#   ...
#   [  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]]]
# [[[  0 128 255 255]
#   [  0 128 255 255]
#   [  0 128 255 255]
#   ...
#   [  0 128 255 255]
#   [  0 128 255 255]
# ...

# %%
plt.imshow(imgdata)

# %%
img = cv2.imread("tiled/man.png", cv2.IMREAD_UNCHANGED)
img = cv2.cvtColor(img, cv2.COLOR_BGRA2RGBA)
# plt.imshow(img[:img.shape[0]//2, :img.shape[1]//2])
tiles = split_image(img, 3,4)
plt.imshow(tiles[3])

# %%
img = cv2.imread("player/down.png", cv2.IMREAD_UNCHANGED)
img = cv2.cvtColor(img, cv2.COLOR_BGRA2RGBA)
plt.imshow(img[:img.shape[0]//2, :img.shape[1]//2])
tiles = split(img, 2,2)

# %%
plt.imshow(tiles[3])

# %%
# %matplotlib notebook

import random
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

import matplotlib.animation as animation


fps = 30
nSeconds = 5
snapshots = tiles*100

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure( figsize=(8,8) )

a = snapshots[0]
im = plt.imshow(a, interpolation='none', aspect='auto', vmin=0, vmax=1)

def animate_func(i):
    if i % fps == 0:
        print( '.', end ='' )

    im.set_array(snapshots[i])
    return [im]

anim = animation.FuncAnimation(
                               fig, 
                               animate_func, 
                               frames = nSeconds * fps,
                               interval = 1000 / fps, # in ms
                               )

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Tilesheet information:
#
# Tile size
# - 16px × 16px
# Space between tiles
# - 1px × 1px
#
# Total tiles (horizontal)
# - 37 tiles
# Total tiles (vertical)
# - 28 tiles
#
# Total tiles in sheet
# - 1036 tiles

# %%
import pytmx
from pytmx.util_pygame import load_pygame
tmxdata = load_pygame("tiled/boolground.tmx")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import pytmx
#       2 from pytmx.util_pygame import load_pygame
# ----> 3 tmxdata = load_pygame("tiled/boolground.tmx")
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/pytmx/util_pygame.py:183, in load_pygame(filename, *args, **kwargs)
#     157 """Load a TMX file, images, and return a TiledMap class
#     158
#     159 PYGAME USERS: Use me.
#    (...)
#     180
#     181 """
#     182 kwargs["image_loader"] = pygame_image_loader
# --> 183 return pytmx.TiledMap(filename, *args, **kwargs)
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/pytmx/pytmx.py:501, in TiledMap.__init__(self, filename, image_loader, **kwargs)
#     498 self.imagemap[(0, 0)] = 0
#     500 if filename:
# --> 501     self.parse_xml(ElementTree.parse(self.filename).getroot())
#
# ...
